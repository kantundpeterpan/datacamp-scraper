# %%
from bs4 import BeautifulSoup			  #For parsing the HTML
from collections import OrderedDict		#For storing chapter and lesson info
from subprocess import Popen, PIPE, STDOUT #For accessing pandoc
from urllib.request import urlopen
from urllib.request import urlretrieve		 #For fetching the webpage
import json								#For dealing with website data that comes in JSON
import pandas as pd						#For create Zettelkasten-style filenames
import re								  #For regex parsing of `sct`
import subprocess						  #For accessing pandoc
import pprint

# %%
def get_whole_course(link, return_z=False):
	'''Receives course URL from user. Gets ordered dict of chapters/lessons. 
	Creates list of unique z_numbers, one for each chapter. 
	Creates txt file for each chapter, fills each file with lesson content.
	Gets course name. Creates table of contents.
	Feeds to: get_course_outline(), make_z_number(), make_chapter_notes(), 
	get_course_title(), create_table_of_contents()'''
	course_dictionary = get_course_outline(link)
	z_list = make_z_number(len(course_dictionary.items())+1)
	for chapter, lesson in course_dictionary.items():
		z_index = list(course_dictionary.keys()).index(chapter)
		filename = z_list[z_index] + ' ' + chapter + '.txt'
		chapter_link = [lesson][0][1][1] 
		make_chapter_notes(filename, chapter_link)
	course_name = get_course_title(link)
	create_table_of_contents(course_dictionary, course_name, z_list)
	if return_z == True:
		return z_list[-1]

def get_course_outline(link):
	'''Receives link to course landing page from get_whole_course(). 
	Returns ordered dict of chapters with lessons.'''
	html = urlopen(link)
	soup = BeautifulSoup(html, 'lxml')
	lesson_outline = soup.find_all(['h4', 'li'])
	chapters = OrderedDict()   # {chapter: [(lesson_name, lesson_link), ...], ...}
	for item in lesson_outline:
		attributes = item.attrs
		try:
			class_type = attributes['class'][0]
			if class_type == 'chapter__title':
				chapter = item.text.strip()
				chapters[chapter] = []
			if class_type == 'chapter__exercise':
				lesson_name = item.find('h5').text
				lesson_link = item.find('a').attrs['href']
				chapters[chapter].append((lesson_name, lesson_link))
		except KeyError:
			pass
	return(chapters)

def make_z_number(num):
	'''Takes int and returns a list of unique, 14-digit numbers. Only goes to 99.'''
	assert num < 100, 'Enter an int that is less than 100. Max list size is 99.'
	string_list = []
	z_index = 0
	for x in range(num):
		z_string = pd.to_datetime('now').strftime('%Y%m%d%H%S') #Did seconds instead of minutes to avoid repeats
		z_string = z_string + '{0:0>2}'.format(z_index)
		string_list.append(z_string)
		z_index += 1
	return string_list

def make_chapter_notes(filename, link):
	'''Receives filename and lesson link from get_whole_course().
	(Note that a link from any lesson in a chapter will work. 
    That is, any lesson link has all the information for the chapter.)
	Cycles through all lessons in chapter, converting each lesson and sub-exercise from HTML to Markdown.
	Prints all chapter content into text file.
	Feeds to: get_lesson_json(), NormalExercise_print(), BulletExercise_print(), 
	MultipleChoiceExercise_print(), download_chapter_slides()'''
	print("Start chapter notes")
	lesson_json = get_lesson_json(link)
	for item in lesson_json['exercises']['all']:
		if item['type'] == 'VideoExercise':
			pass
		elif item['type'] == 'NormalExercise':
			NormalExercise_print(item, filename)
		elif item['type'] == 'BulletExercise':
			BulletExercise_print(item, filename)
		elif item['type'] == 'MultipleChoiceExercise':
			MultipleChoiceExercise_print(item, filename)
	print("Made text file")
	download_chapter_slides(lesson_json, filename.strip('.txt'))
	print("Downloaded notes")

def get_course_title(link):
	html = urlopen(link)
	soup = BeautifulSoup(html, 'lxml')
	return soup.title.text

def create_table_of_contents(dictionary, course_name, z_list):
	'''Receives course dictionary, course name, and list of unique z_numbers from get_whole_course().
    Creates text file with contents of course, formatted in Markdown, with wiki-style links to each chapter.'''    
	filename = z_list[-1] + ' ' + course_name + '.txt'
	with open(filename, 'a') as f:
		for chapter, lessons in dictionary.items():
			z_index = list(dictionary.keys()).index(chapter)
			print('\n# ', '[[' + z_list[z_index] + ']]', chapter, '\n', file=f)
			for lesson_name, lesson_link in lessons:
				print("   *", lesson_name, file=f)

def get_lesson_json(link):
	'''Receives lesson link from make_chapter_notes() and returns 
	the dictionary that holds all the information for the lesson's parent chapter.'''
	html = urlopen(link)
	soup = BeautifulSoup(html, 'lxml')
	string = soup.find_all('script')[3].string
	json_text = string.strip('window.PRELOADED_STATE=')[:-1]
	lesson_json = json.loads(json_text)
	return lesson_json
                
def NormalExercise_print(json, f):
	'''Works with make_chapter_notes. Parses NormalExercise type lessons and prints them in 
	markdown to file.
	Feeds to: convert_2_md(), get_success_msg().'''
	with open(f, 'a') as f:
		print('#', json['title'], '\n', file=f)
		print('## Exercise\n', file=f)
		print(convert_2_md(json['assignment']), file=f)
		print('## Instructions\n', file=f)
		print(convert_2_md(json['instructions'][:-2]), file=f)
		print('## Code\n', file=f)
		print('```\n' + convert_2_md(json['sample_code']).replace('\\', ''),'\n```\n', file=f)
		print('```\n' + convert_2_md(json['solution']).replace('\\', ''),'\n```\n', file=f)
		print(get_success_msg(json['sct']) + '\n', file=f)

def BulletExercise_print(json, f):
	'''Works with make_chapter_notes. Parses BulletExercises type lessons and prints them in 
	markdown to file.
	Feeds to: convert_2_md(), get_success_msg().'''
	with open(f, 'a') as f:
		print('# ' + json['title'], '\n', file=f)
		print('## Exercise\n', file=f)
		print(convert_2_md(json['assignment']), file=f)
		print('## Instructions & Code \n', file=f)  
		for item in json['subexercises']:
			print(convert_2_md(item['instructions']), file=f)
			print('```\n' + item['sample_code'] + '\n```\n', file=f)
			print('```\n' + item['solution']	+ '\n```', file=f)
			print(get_success_msg(item['sct']) + '\n', file=f)

def MultipleChoiceExercise_print(json, f):
	'''Works with make_chapter_notes. Parses MultipleChoice type lessons and prints them in 
	markdown to file.
	Feeds to: convert_2_md(), get_correct_mc(), get_success_msg().'''
	with open(f, 'a') as f:
		print('# ' + json['title'], '\n', file=f)
		print('## Exercise\n', file=f)
		print(convert_2_md(json['assignment']), file=f)
		print("## Choices\n", file=f)
		for choice in json['instructions']:
			print('* ' + choice, file=f)
		print('\n**Correct answer: ' + get_correct_mc(json['sct']) + '**\n', file=f)
		print(get_success_msg(json['sct']) + '\n', file=f)

def convert_2_md(string):
	'''Receives a string of HTML and use Pandoc to return string in Markdown.'''
	p = Popen(['pandoc', '-f', 'html', '-t', 'markdown', '--wrap=preserve'], stdout=PIPE, stdin=PIPE, stderr=STDOUT)
	text = p.communicate(input=string.encode('utf-8'))[0]
	text = text.decode('utf-8')
	return text

def get_success_msg(string):
	'''Parses text from DataCamp `sct` JSON and returns the success message as a string.'''
	match = re.search(r'success_msg\("(.*?)"\)', string)
	if match != None:
		message = match.group(1)
		return message
	else:
		return ''

def get_correct_mc(string):
	'''Parses text from DataCamp `sct` JSON and correct answer for MultipleChoice type lessons. 
    Works with MultipleChoiceExercise_print'''
	match = re.search(r'test_mc\(correct = (\d),', string)
	if match != None:
		message = match.group(1)
		return message
	else:
		return ''

def download_chapter_slides(lesson_json, filename):
	'''Receives lesson_json and filename from make_chapter_notes(). 
	Finds link to PDF of slides for each chapter. 
	Saves PDF with chapter's unique z_number and title.'''
	for item in lesson_json['course']['chapters']:
		url = item['slides_link']
		urlretrieve(url, filename + '.pdf')

# %%
link = 'https://www.datacamp.com/courses/experimental-design-in-r'
get_whole_course(link)
# Out:
# Start chapter notes
# Made text file
# Downloaded notes
# Start chapter notes
# Made text file
# Downloaded notes
# Start chapter notes
# Made text file
# Downloaded notes
# Start chapter notes

# %%
def scrape_datacamp_track(link):
    html = urlopen(link)
    soup = BeautifulSoup(html, 'lxml')
    track = soup.find_all('a', attrs={'class':'course-block__link ds-snowplow-link-course-block'})
    courses = []

    for x in track:
        title = x.find('h4').text
        tail = x.attrs['href']
        url = 'https://www.datacamp.com' + tail
        courses.append((title, url))
    
    for course in courses:
        z_num = get_whole_course(course[1], return_z=True)

# %%
pd.to_datetime('now').strftime('%Y%m%d%H%S')
# Out:
# '201808081608'

# %%
get_course_outline(link)
# Out:
# OrderedDict([('Introduction to Experimental Design',
#               [('Intro to Experimental Design',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/introduction-to-experimental-design?ex=1'),
#                ('A basic experiment',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/introduction-to-experimental-design?ex=2'),
#                ('Randomization',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/introduction-to-experimental-design?ex=3'),
#                ('Replication',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/introduction-to-experimental-design?ex=4'),
#                ('Blocking',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/introduction-to-experimental-design?ex=5'),
#                ('Hypothesis Testing',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/introduction-to-experimental-design?ex=6'),
#                ('One sided vs. Two sided tests',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/introduction-to-experimental-design?ex=7'),
#                ('pwr package Help Docs exploration',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/introduction-to-experimental-design?ex=8'),
#                ('Power & Sample Size Calculations',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/introduction-to-experimental-design?ex=9')]),
#              ('Basic Experiments',
#               [('Single & Multiple Factor Experiments',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/basic-experiments?ex=1'),
#                ('Exploratory Data Analysis (EDA) Lending Club',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/basic-experiments?ex=2'),
#                ('How does loan purpose affect amount funded?',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/basic-experiments?ex=3'),
#                ('Which loan purpose mean is different?',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/basic-experiments?ex=4'),
#                ('Multiple Factor Experiments',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/basic-experiments?ex=5'),
#                ('Model Validation',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/basic-experiments?ex=6'),
#                ('Pre-modeling EDA',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/basic-experiments?ex=7'),
#                ('Post-modeling validation plots + variance',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/basic-experiments?ex=8'),
#                ('Kruskal-Wallis rank sum test',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/basic-experiments?ex=9'),
#                ('A/B Testing',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/basic-experiments?ex=10'),
#                ('Which post-A/B test test?',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/basic-experiments?ex=11'),
#                ('Sample size for A/B test',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/basic-experiments?ex=12'),
#                ('Basic A/B test',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/basic-experiments?ex=13'),
#                ('A/B tests vs. multivariable experiments',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/basic-experiments?ex=14')]),
#              ('Randomized Complete (& Balanced Incomplete) Block Designs',
#               [('Intro to NHANES dataset & Sampling',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/randomized-complete-balanced-incomplete-block-designs?ex=1'),
#                ('NHANES dataset construction',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/randomized-complete-balanced-incomplete-block-designs?ex=2'),
#                ('NHANES EDA',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/randomized-complete-balanced-incomplete-block-designs?ex=3'),
#                ('NHANES Data Cleaning',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/randomized-complete-balanced-incomplete-block-designs?ex=4'),
#                ('Resampling NHANES data',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/randomized-complete-balanced-incomplete-block-designs?ex=5'),
#                ('Randomized Complete Block Designs (RCBD)',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/randomized-complete-balanced-incomplete-block-designs?ex=6'),
#                ('Which is NOT a good blocking factor?',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/randomized-complete-balanced-incomplete-block-designs?ex=7'),
#                ('Drawing RCBDs with Agricolae',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/randomized-complete-balanced-incomplete-block-designs?ex=8'),
#                ('NHANES RCBD',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/randomized-complete-balanced-incomplete-block-designs?ex=9'),
#                ('RCBD Model Validation',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/randomized-complete-balanced-incomplete-block-designs?ex=10'),
#                ('Balanced Incomplete Block Designs (BIBD)',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/randomized-complete-balanced-incomplete-block-designs?ex=11'),
#                ('Is a BIBD even possible?',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/randomized-complete-balanced-incomplete-block-designs?ex=12'),
#                ('Drawing BIBDs with agricolae',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/randomized-complete-balanced-incomplete-block-designs?ex=13'),
#                ("BIBD - cat's kidney function",
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/randomized-complete-balanced-incomplete-block-designs?ex=14'),
#                ('NHANES BIBD',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/randomized-complete-balanced-incomplete-block-designs?ex=15')]),
#              ('Latin Squares, Graeco-Latin Squares, & Factorial experiments',
#               [('Latin Squares',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/latin-squares-graeco-latin-squares-factorial-experiments?ex=1'),
#                ('NYC SAT Scores EDA',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/latin-squares-graeco-latin-squares-factorial-experiments?ex=2'),
#                ('Dealing with Missing Test Scores',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/latin-squares-graeco-latin-squares-factorial-experiments?ex=3'),
#                ('Drawing Latin Squares with agricolae',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/latin-squares-graeco-latin-squares-factorial-experiments?ex=4'),
#                ('Latin Square with NYC SAT Scores',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/latin-squares-graeco-latin-squares-factorial-experiments?ex=5'),
#                ('Graeco-Latin Squares',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/latin-squares-graeco-latin-squares-factorial-experiments?ex=6'),
#                ('NYC SAT Scores Data Viz',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/latin-squares-graeco-latin-squares-factorial-experiments?ex=7'),
#                ('Drawing Graeco-Latin Squares with agricolae',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/latin-squares-graeco-latin-squares-factorial-experiments?ex=8'),
#                ('Graeco-Latin Square with NYC SAT Scores',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/latin-squares-graeco-latin-squares-factorial-experiments?ex=9'),
#                ('Factorial Experiments',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/latin-squares-graeco-latin-squares-factorial-experiments?ex=10'),
#                ('NYC SAT Scores Factorial EDA',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/latin-squares-graeco-latin-squares-factorial-experiments?ex=11'),
#                ('Factorial Experiment with NYC SAT Scores',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/latin-squares-graeco-latin-squares-factorial-experiments?ex=12'),
#                ('Evaluating the NYC SAT Scores Factorial Model',
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/latin-squares-graeco-latin-squares-factorial-experiments?ex=13'),
#                ("What's next in Experimental Design",
#                 'https://campus.datacamp.com/courses/experimental-design-in-r/latin-squares-graeco-latin-squares-factorial-experiments?ex=14')])])

# %%
def get_course_outline(link):
	'''Receives link to course landing page from get_whole_course(). 
	Returns ordered dict of chapters with lessons.'''
	html = urlopen(link)
	soup = BeautifulSoup(html, 'lxml')
	lesson_outline = soup.find_all(['h4', 'li'])
	chapters = OrderedDict()   # {chapter: [(lesson_name, lesson_link), ...], ...}
	for item in lesson_outline:
		attributes = item.attrs
		try:
			class_type = attributes['class'][0]
			if class_type == 'chapter__title':
				chapter = item.text.strip()
				chapters[chapter] = []
			if class_type == 'chapter__exercise':
				lesson_name = item.find('h5').text
				lesson_link = item.find('a').attrs['href']
				chapters[chapter].append((lesson_name, lesson_link))
		except KeyError:
			pass
	return(chapters)

# %%
html = urlopen(link)
soup = BeautifulSoup(html, 'lxml')
lesson_outline = soup.find_all(['h4', 'li'])

# %%
for item in lesson_outline:
	attributes = item.attrs
	try:
		class_type = attributes['class'][0]
		if class_type == 'chapter__title':
			chapter = item.text.strip()
			print(chapter)
		if class_type == 'chapter__exercise':
			print(item.find('h5').text)
			print(item.find('a').attrs['href'])
	except KeyError:
		pass
# Out:
# Introduction to Experimental Design
# Intro to Experimental Design
# https://campus.datacamp.com/courses/experimental-design-in-r/introduction-to-experimental-design?ex=1
# A basic experiment
# https://campus.datacamp.com/courses/experimental-design-in-r/introduction-to-experimental-design?ex=2
# Randomization
# https://campus.datacamp.com/courses/experimental-design-in-r/introduction-to-experimental-design?ex=3
# Replication
# https://campus.datacamp.com/courses/experimental-design-in-r/introduction-to-experimental-design?ex=4
# Blocking
# https://campus.datacamp.com/courses/experimental-design-in-r/introduction-to-experimental-design?ex=5
# Hypothesis Testing
# https://campus.datacamp.com/courses/experimental-design-in-r/introduction-to-experimental-design?ex=6
# One sided vs. Two sided tests
# https://campus.datacamp.com/courses/experimental-design-in-r/introduction-to-experimental-design?ex=7
# pwr package Help Docs exploration
# https://campus.datacamp.com/courses/experimental-design-in-r/introduction-to-experimental-design?ex=8
# Power & Sample Size Calculations
# https://campus.datacamp.com/courses/experimental-design-in-r/introduction-to-experimental-design?ex=9
# Basic Experiments
# Single & Multiple Factor Experiments
# https://campus.datacamp.com/courses/experimental-design-in-r/basic-experiments?ex=1
# Exploratory Data Analysis (EDA) Lending Club
# https://campus.datacamp.com/courses/experimental-design-in-r/basic-experiments?ex=2
# How does loan purpose affect amount funded?
# https://campus.datacamp.com/courses/experimental-design-in-r/basic-experiments?ex=3
# Which loan purpose mean is different?
# https://campus.datacamp.com/courses/experimental-design-in-r/basic-experiments?ex=4
# Multiple Factor Experiments
# https://campus.datacamp.com/courses/experimental-design-in-r/basic-experiments?ex=5
# Model Validation
# https://campus.datacamp.com/courses/experimental-design-in-r/basic-experiments?ex=6
# Pre-modeling EDA
# https://campus.datacamp.com/courses/experimental-design-in-r/basic-experiments?ex=7
# Post-modeling validation plots + variance
# https://campus.datacamp.com/courses/experimental-design-in-r/basic-experiments?ex=8
# Kruskal-Wallis rank sum test
# https://campus.datacamp.com/courses/experimental-design-in-r/basic-experiments?ex=9
# A/B Testing
# https://campus.datacamp.com/courses/experimental-design-in-r/basic-experiments?ex=10
# Which post-A/B test test?
# https://campus.datacamp.com/courses/experimental-design-in-r/basic-experiments?ex=11
# Sample size for A/B test
# https://campus.datacamp.com/courses/experimental-design-in-r/basic-experiments?ex=12
# Basic A/B test
# https://campus.datacamp.com/courses/experimental-design-in-r/basic-experiments?ex=13
# A/B tests vs. multivariable experiments
# https://campus.datacamp.com/courses/experimental-design-in-r/basic-experiments?ex=14
# Randomized Complete (& Balanced Incomplete) Block Designs
# Intro to NHANES dataset & Sampling
# https://campus.datacamp.com/courses/experimental-design-in-r/randomized-complete-balanced-incomplete-block-designs?ex=1
# NHANES dataset construction
# https://campus.datacamp.com/courses/experimental-design-in-r/randomized-complete-balanced-incomplete-block-designs?ex=2
# NHANES EDA
# https://campus.datacamp.com/courses/experimental-design-in-r/randomized-complete-balanced-incomplete-block-designs?ex=3
# NHANES Data Cleaning
# https://campus.datacamp.com/courses/experimental-design-in-r/randomized-complete-balanced-incomplete-block-designs?ex=4
# Resampling NHANES data
# https://campus.datacamp.com/courses/experimental-design-in-r/randomized-complete-balanced-incomplete-block-designs?ex=5
# Randomized Complete Block Designs (RCBD)
# https://campus.datacamp.com/courses/experimental-design-in-r/randomized-complete-balanced-incomplete-block-designs?ex=6
# Which is NOT a good blocking factor?
# https://campus.datacamp.com/courses/experimental-design-in-r/randomized-complete-balanced-incomplete-block-designs?ex=7
# Drawing RCBDs with Agricolae
# https://campus.datacamp.com/courses/experimental-design-in-r/randomized-complete-balanced-incomplete-block-designs?ex=8
# NHANES RCBD
# https://campus.datacamp.com/courses/experimental-design-in-r/randomized-complete-balanced-incomplete-block-designs?ex=9
# RCBD Model Validation
# https://campus.datacamp.com/courses/experimental-design-in-r/randomized-complete-balanced-incomplete-block-designs?ex=10
# Balanced Incomplete Block Designs (BIBD)
# https://campus.datacamp.com/courses/experimental-design-in-r/randomized-complete-balanced-incomplete-block-designs?ex=11
# Is a BIBD even possible?
# https://campus.datacamp.com/courses/experimental-design-in-r/randomized-complete-balanced-incomplete-block-designs?ex=12
# Drawing BIBDs with agricolae
# https://campus.datacamp.com/courses/experimental-design-in-r/randomized-complete-balanced-incomplete-block-designs?ex=13
# BIBD - cat's kidney function
# https://campus.datacamp.com/courses/experimental-design-in-r/randomized-complete-balanced-incomplete-block-designs?ex=14
# NHANES BIBD
# https://campus.datacamp.com/courses/experimental-design-in-r/randomized-complete-balanced-incomplete-block-designs?ex=15
# Latin Squares, Graeco-Latin Squares, & Factorial experiments
# Latin Squares
# https://campus.datacamp.com/courses/experimental-design-in-r/latin-squares-graeco-latin-squares-factorial-experiments?ex=1
# NYC SAT Scores EDA
# https://campus.datacamp.com/courses/experimental-design-in-r/latin-squares-graeco-latin-squares-factorial-experiments?ex=2
# Dealing with Missing Test Scores
# https://campus.datacamp.com/courses/experimental-design-in-r/latin-squares-graeco-latin-squares-factorial-experiments?ex=3
# Drawing Latin Squares with agricolae
# https://campus.datacamp.com/courses/experimental-design-in-r/latin-squares-graeco-latin-squares-factorial-experiments?ex=4
# Latin Square with NYC SAT Scores
# https://campus.datacamp.com/courses/experimental-design-in-r/latin-squares-graeco-latin-squares-factorial-experiments?ex=5
# Graeco-Latin Squares
# https://campus.datacamp.com/courses/experimental-design-in-r/latin-squares-graeco-latin-squares-factorial-experiments?ex=6
# NYC SAT Scores Data Viz
# https://campus.datacamp.com/courses/experimental-design-in-r/latin-squares-graeco-latin-squares-factorial-experiments?ex=7
# Drawing Graeco-Latin Squares with agricolae
# https://campus.datacamp.com/courses/experimental-design-in-r/latin-squares-graeco-latin-squares-factorial-experiments?ex=8
# Graeco-Latin Square with NYC SAT Scores
# https://campus.datacamp.com/courses/experimental-design-in-r/latin-squares-graeco-latin-squares-factorial-experiments?ex=9
# Factorial Experiments
# https://campus.datacamp.com/courses/experimental-design-in-r/latin-squares-graeco-latin-squares-factorial-experiments?ex=10
# NYC SAT Scores Factorial EDA
# https://campus.datacamp.com/courses/experimental-design-in-r/latin-squares-graeco-latin-squares-factorial-experiments?ex=11
# Factorial Experiment with NYC SAT Scores
# https://campus.datacamp.com/courses/experimental-design-in-r/latin-squares-graeco-latin-squares-factorial-experiments?ex=12
# Evaluating the NYC SAT Scores Factorial Model
# https://campus.datacamp.com/courses/experimental-design-in-r/latin-squares-graeco-latin-squares-factorial-experiments?ex=13
# What's next in Experimental Design
# https://campus.datacamp.com/courses/experimental-design-in-r/latin-squares-graeco-latin-squares-factorial-experiments?ex=14
